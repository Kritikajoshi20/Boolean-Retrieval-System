# %%
#NLTK Initialization and Setup
# !pip install -U nltk
# !pip install emoji
# !python -m nltk.downloader punkt_tab
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.12.1)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from emoji) (4.12.2)
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
import numpy as np
import pandas as pd
import nltk
import re
import emoji
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import os
import string
import logging
from collections import defaultdict , Counter

# %% [markdown]
# **Loading_Text_Files**

# %%
import os
import logging

# Function to load .txt files from a specified folder
def load_text_files(folder_path):
    """
    Reads all .txt files in a folder and returns a
    dictionary with filenames as keys and content as values.
    """
    data = {}  # Dictionary to store document content with doc_id as key
    doc_id_to_filename = {}  # Dictionary to map doc_id to filename
    doc_id = 0  # Initialize document ID

    # Iterate over files in the specified folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):  # Process only .txt files
            file_path = os.path.join(folder_path, filename)

            # Open and read the file content
            with open(file_path, 'r', encoding='utf-8') as file:
                data[doc_id] = file.read()  # Store the content of the file
                doc_id_to_filename[doc_id] = filename  # Map doc_id to filename

                # Log the loading of the file
                logging.info(f"Loaded file: {filename} with doc_id: {doc_id}")

            doc_id += 1  # Increment document ID for the next file

    # Return the dictionary containing file content and the mapping of doc_ids to filenames
    return data, doc_id_to_filename

# %%
# Set up logging
logging.basicConfig(level=logging.INFO)

# Specify the folder path
folder_path = '/content/drive/MyDrive/Documents' # This is the directory containing the files

# Load the text files
document_data, doc_id_to_filename = load_text_files(folder_path)

# Example to access the data
print(document_data)
print(doc_id_to_filename)
# Out:
# {0: 'Python Data Types: \nEvery value has a datatype, and variables can hold values. Python is a powerfully composed language; consequently, we don\'t have to characterize the sort of variable while announcing it. The interpreter binds the value implicitly to its type.\n\na = 5  \nWe did not specify the type of the variable a, which has the value five from an integer. The Python interpreter will automatically interpret the variable as an integer.\n\nWe can verify the type of the program-used variable thanks to Python. The type() function in Python returns the type of the passed variable.\n\nConsider the following illustration when defining and verifying the values of various data types.\nADVERTISEMENT\n\na=10  \nb="Hi Python"  \nc = 10.5  \nprint(type(a))  \nprint(type(b))  \nprint(type(c))  \nOutput:\n\n<type \'int\'>\n<type \'str\'>\n<type \'float\'>\nStandard data types\nA variable can contain a variety of values. On the other hand, a person\'s id must be stored as an integer, while their name must be stored as a string.\n\nThe storage method for each of the standard data types that Python provides is specified by Python. The following is a list of the Python-defined data types.\n\nNumbers\nSequence Type\nBoolean\nSet\nDictionary\nPython Data Types\nThe data types will be briefly discussed in this tutorial section. We will talk about every single one of them exhaustively later in this instructional exercise.\n\nNumbers\nNumeric values are stored in numbers. The whole number, float, and complex qualities have a place with a Python Numbers datatype. Python offers the type() function to determine a variable\'s data type. The instance () capability is utilized to check whether an item has a place with a specific class.\n\nWhen a number is assigned to a variable, Python generates Number objects. For instance,\nADVERTISEMENT\nADVERTISEMENT\n\na = 5  \nprint("The type of a", type(a))  \n  \nb = 40.5  \nprint("The type of b", type(b))  \n  \nc = 1+3j  \nprint("The type of c", type(c))  \nprint(" c is a complex number", isinstance(1+3j,complex))  \nOutput:\n\nThe type of a <class \'int\'>\nThe type of b <class \'float\'>\nThe type of c <class \'complex\'>\nc is complex number: True\nPython supports three kinds of numerical data.\nReference: https://www.javatpoint.com/python-data-types ', 1: 'Python Literals\nPython Literals can be defined as data that is given in a variable or constant.\n\nPython supports the following literals:\n\n1. String literals:\nString literals can be formed by enclosing a text in the quotes. We can use both single as well as double quotes to create a string.\n\nExample:\nADVERTISEMENT\n\n"Aman" , \'12345\'  \nTypes of Strings:\n\nThere are two types of Strings supported in Python:\n\na) Single-line String- Strings that are terminated within a single-line are known as Single line Strings.\n\nExample:\n\ntext1=\'hello\'  \nb) Multi-line String - A piece of text that is written in multiple lines is known as multiple lines string.\n\nThere are two ways to create multiline strings:\nADVERTISEMENT\nADVERTISEMENT\n\n1) Adding black slash at the end of each line.\n\nExample:\n\ntext1=\'hello\\    \nuser\'    \nprint(text1)  \n\'hellouser\'\n2) Using triple quotation marks:-\n\nExample:\n\nstr2=\'\'\'\'\'welcome  \nto  \nSSSIT\'\'\'    \nprint str2   \nOutput:\n\nwelcome\nto\nSSSIT\nReference: https://www.javatpoint.com/python-literals', 2: 'Python Tuples\nA comma-separated group of items is called a Python triple. The ordering, settled items, and reiterations of a tuple are to some degree like those of a rundown, but in contrast to a rundown, a tuple is unchanging.\n\nThe main difference between the two is that we cannot alter the components of a tuple once they have been assigned. On the other hand, we can edit the contents of a list.\n\nExample\n\n("Suzuki", "Audi", "BMW"," Skoda ") is a tuple.  \nFeatures of Python Tuple\nADVERTISEMENT\n\nAny number of items, including those with various data types (dictionary, s ...
# {0: 'Doc_2.txt', 1: 'Doc_3.txt', 2: 'Doc_4.txt', 3: 'Doc_5.txt', 4: 'Doc_1.txt'}

# %% [markdown]
# **Text Cleaning Pipeline**

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Initialize lemmatizer and stopwords
LEMMATIZER = WordNetLemmatizer()
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """Performs text cleaning: removing special characters, numbers, tokenization, stopword removal, and lemmatization."""

    # Convert to lowercase
    text = text.lower()

    # Remove special characters and numbers using regular expressions
    # Keeps only alphabetic characters and spaces
    text = re.sub(r"[^a-zA-Z\s]", "", text)

    # Tokenize the cleaned text
    tokens = word_tokenize(text)

    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove mentions (@usernames)
    text = re.sub(r'@\w+', '', text)

    # Remove hashtags
    text = re.sub(r'#\w+', '', text)

    # Retain apostrophes in contractions, remove other special characters
    text = re.sub(r"[^a-zA-Z\s']", '', text)

    # Remove extra whitespaces
    text = re.sub(r'\s+', ' ', text).strip()

    # Convert emojis to descriptive text
    text = emoji.demojize(text)

    # Convert tokens to lowercase
    tokens_lower = [token.lower() for token in tokens]

    # Manually preserve contractions to ensure they're not split
    contractions = ["n't", "'m", "'re", "'ve", "'ll", "'s", "'d"]
    tokens_preserved = []
    for token in tokens_lower:
        # Reattach contraction endings if separated
        if token in contractions and tokens_preserved:
            tokens_preserved[-1] += token
        else:
            tokens_preserved.append(token)

    # Step 4: Remove stopwords and lemmatize
    cleaned_tokens = [LEMMATIZER.lemmatize(word) for word in tokens if word not in STOPWORDS]

    return cleaned_tokens

# Example usage:
documents = [
    "Doc_1: Python Variables: A variable is the name given to a memory location. It has 5 types.",
    "Doc_2: Python Data Types: Every value has a datatype, and variables can hold values. Numbers like 12345 are removed.",
    "Doc_3: Python Literals: Python Literals can be defined as data that is given in a variable or constant like 789.",
    "Doc_4: Python Tuples: A comma-separated group of items is called a Python triple with 3 values.",
    "Doc_5: Python Arrays: The Array is used in every programming language like C, C++, Java, Python, R, JavaScript."
]

cleaned_documents = [clean_text(doc) for doc in documents]
print(cleaned_documents)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [['doc', 'python', 'variable', 'variable', 'name', 'given', 'memory', 'location', 'type'], ['doc', 'python', 'data', 'type', 'every', 'value', 'datatype', 'variable', 'hold', 'value', 'number', 'like', 'removed'], ['doc', 'python', 'literal', 'python', 'literal', 'defined', 'data', 'given', 'variable', 'constant', 'like'], ['doc', 'python', 'tuples', 'commaseparated', 'group', 'item', 'called', 'python', 'triple', 'value'], ['doc', 'python', 'array', 'array', 'used', 'every', 'programming', 'language', 'like', 'c', 'c', 'java', 'python', 'r', 'javascript']]

# %% [markdown]
# **Construction of Inverted Index**

# %%
from collections import defaultdict, Counter
import re
import os

def clean_text(text):
    # Convert to lowercase and remove special characters using regular expressions
    return re.sub(r'[^a-zA-Z0-9\s]', '', text.lower()).split()

def build_inverted_index(data):

    inverted_index = defaultdict(set)  # Initialize an empty inverted index
    term_frequencies = Counter()  # Initialize a counter for term frequencies

    for doc_id, content in data.items():
        cleaned_tokens = clean_text(content)  # Clean the text content

        for token in cleaned_tokens:
            inverted_index[token].add(doc_id)  # Add the document ID to the inverted index
            term_frequencies[token] += 1  # Update the term frequency

    return inverted_index, term_frequencies

# Specify the folder path
folder_path = '/content/drive/MyDrive/Documents'

# Load the text files from the directory
data = {}
doc_id = 1
for filename in os.listdir(folder_path):
    if filename.endswith(".txt"):
        with open(os.path.join(folder_path, filename), 'r') as file:
            text = file.read()
            data[doc_id] = text
            doc_id += 1

# Build the inverted index
inverted_index, term_frequencies = build_inverted_index(data)

# Print the inverted index
print("Inverted Index:")
for token, doc_ids in inverted_index.items():
    print(f"{token}: {doc_ids}")

# Print the term frequencies
print("\nTerm Frequencies:")
for token, frequency in term_frequencies.items():
    print(f"{token}: {frequency}")
# Out:
# Inverted Index:
# python: {1, 2, 3, 4, 5}
# data: {1, 2, 3, 4}
# types: {1, 2, 3}
# every: {1, 4}
# value: {1, 4, 5}
# has: {1}
# a: {1, 2, 3, 4, 5}
# datatype: {1}
# and: {1, 3, 4, 5}
# variables: {1, 5}
# can: {1, 2, 3, 4, 5}
# hold: {1}
# values: {1, 4}
# is: {1, 2, 3, 4, 5}
# powerfully: {1}
# composed: {1}
# language: {1, 4, 5}
# consequently: {1}
# we: {1, 2, 3, 4, 5}
# dont: {1}
# have: {1, 3, 4, 5}
# to: {1, 2, 3, 4, 5}
# characterize: {1}
# the: {1, 2, 3, 4, 5}
# sort: {1}
# of: {1, 2, 3, 4, 5}
# variable: {1, 2, 4, 5}
# while: {1}
# announcing: {1}
# it: {1, 4, 5}
# interpreter: {1}
# binds: {1}
# implicitly: {1}
# its: {1, 4, 5}
# type: {1, 5}
# 5: {1, 3, 4}
# did: {1}
# not: {1, 3, 5}
# specify: {1, 5}
# which: {1}
# five: {1}
# from: {1, 4}
# an: {1, 3, 4, 5}
# integer: {1, 5}
# will: {1, 5}
# automatically: {1}
# interpret: {1}
# as: {1, 2, 3, 4, 5}
# verify: {1}
# programused: {1}
# thanks: {1}
# function: {1, 5}
# in: {1, 2, 3, 4, 5}
# returns: {1}
# passed: {1}
# consider: {1}
# following: {1, 2, 5}
# illustration: {1}
# when: {1, 4}
# defining: {1}
# verifying: {1}
# various: {1, 3, 5}
# advertisement: {1, 2, 3, 4, 5}
# a10: {1}
# bhi: {1}
# c: {1, 4, 5}
# 105: {1}
# printtypea: {1}
# printtypeb: {1}
# printtypec: {1}
# output: {1, 2, 3, 4, 5}
# int: {1}
# str: {1, 5}
# float: {1, 3}
# standard: {1}
# contain: {1}
# variety: {1}
# on: {1, 3, 4}
# other: {1, 3}
# hand: {1, 3}
# persons: {1}
# id: {1, 5}
# must: {1, 4, 5}
# be: {1, 2, 3, 4, 5}
# stored: {1}
# their: {1}
# name: {1, 5}
# string: {1, 2, 3, 5}
# storage: {1}
# method: {1}
# for: {1, 3}
# each: {1, 2}
# that: {1, 2, 3, 4, 5}
# provides: {1}
# specified: {1}
# by: {1, 2, 4, 5}
# list: {1, 3}
# pythondefined: {1}
# numbers: {1}
# sequence: {1}
# boolean: {1}
# set: {1}
# dictionary: {1, 3}
# briefly: {1}
# discussed: {1}
# this: {1, 3, 4}
# tutorial: {1}
# section: {1}
# talk: {1}
# about: {1}
# single: {1, 2}
# one: {1, 4}
# them: {1}
# exhaustively: {1}
# later: {1}
# instructional: {1}
# exercise: {1}
# numeric: {1}
# are: {1, 2, 3, 4, 5}
# whole: {1}
# number: {1, 3, 5}
# complex: {1}
# qualities: {1, 5}
# place: {1}
# with: {1, 3, 5}
# offers: {1}
# determine: {1, 5}
# instance: {1}
# capability: {1}
# utilized: {1, 5}
# check: {1, 5}
# whether: {1}
# item: {1, 4, 5}
# specific: {1, 4}
# class: {1, 5}
# assigned: {1, 3, 5}
# generates: {1}
# objects: {1, 3, 5}
# printthe: {1}
# typea: {1}
# b: {1, 2, 5}
# 405: {1}
# typeb: {1}
# 13j: {1}
# typec: {1}
# print: {1, 2, 5}
# isinstance13jcomplex: {1}
# true: {1}
# supports: {1, 2}
# three: {1}
# kinds: {1}
# numerical: {1}
# reference: {1, 2, 3, 4, 5}
# httpswwwjavatpointcompythondatatypes: {1}
# literals: {2, 5}
# defined: {2, 4}
# given: {2, 4, 5}
# or: {2, 5}
# constant: {2}
# 1: {2}
# formed: {2}
# enclosing: {2}
# text: {2}
# quotes: {2}
# use: {2, 4, 5}
# both: {2, 5}
# well: {2}
# double: {2}
# create: {2, 3, 5}
# example: {2, 3, 4, 5}
# aman: {2}
# 12345: {2}
# strings: {2}
# there: {2}
# two: {2, 3, 5}
# supported: {2}
# singleline: {2}
# terminated: {2}
# within: {2}
# known: {2, 3, 5}
# line: {2}
# text1hello: {2}
# multiline: {2}
# piece: {2}
# written: {2}
# multiple: {2}
# lines: {2}
# ways: {2, 5}
# adding: {2}
# black: {2}
# slash: {2}
# at: {2, 4, 5}
# end: {2}
# user: {2}
# printtext1: {2}
# hellouser: {2}
# 2: {2, 3, 4}
# using: {2, 4}
# triple: {2, 3}
# quotation: {2}
# marks: {2}
# str2welcome: {2}
# sssit: {2}
# str2: {2}
# welcome: {2}
# httpswwwjavatpointcompythonliterals: {2}
# tuples: {3}
# commaseparated: {3}
# group: {3, 5}
# items: {3}
# called: {3}
# ordering: {3}
# settled: {3}
# reiterations: {3}
# tuple: {3}
# some: {3}
# degree: {3}
# like: {3, 4, 5}
# those: {3, 4}
# rundown: {3}
# but: {3, 5}
# contrast: {3}
# unchanging: {3}
# main: {3}
# difference: {3}
# between: {3}
# cannot: {3}
# alter: {3}
# components: {3}
# once: {3}
# they: {3, 5}
# been: {3}
# edit: {3}
# contents: {3}
# suzuki: {3}
# audi: {3}
# bmw: {3}
# skoda: {3}
# features: {3}
# any: {3}
# including: {3}
# etc: {3, 4}
# contained: {3}
# code: {3, 4}
# program: {3, 5}
# show: {3}
# how: {3, 4}
# creating: {3}
# empty: {3}
# emptytuple: {3}
# printempty: {3}
# having: {3}
# integers: {3}
# inttuple: {3}
# 4: {3, 4}
# 6: {3, 4}
# 8: {3}
# 10: {3}
# 12: {3}
# 14: {3}
# printtuple: {3}
# different: {3, 5}
# mixedtuple: {3}
# 93: {3}
# nested: {3}
# nestedtuple: {3}
# 82: {3}
# 3: {3}
# printa: {3}
# parentheses: {3}
# necessary: {3}
# construction: {3}
# multiples: {3}
# pressing: {3}
# httpswwwjavatpointcompythontuples: {3}
# arrays: {4}
# introduction: {4}
# article: {4}
# discussing: {4}
# array: {4}
# used: {4, 5}
# programming: {4}
# java: {4}
# r: {4}
# javascript: {4}
# store: {4}
# more: {4}
# than: {4}
# process: {4}
# memory: {4, 5}
# allocation: {4}
# car1: {4}
# lamborghini: {4}
# car2: {4}
# bugatti: {4}
# car3: {4}
# koenigsegg: {4}
# if: {4}
# you: {4}
# want: {4}
# loop: {4}
# through: {4}
# cars: {4}
# find: {4}
# handled: {4}
# module: {4}
# named: {4}
# useful: {4}
# manipulate: {4}
# only: {4}
# traverse: {4}
# prints: {4}
# all: {4}
# elements: {4}
# insertion: {4}
# adds: {4}
# element: {4}
# index: {4}
# deletion: {4}
# deletes: {4}
# import: {4}
# arrayname: {4}
# arraytypecode: {4}
# initializers: {4}
# accessing: {4}
# access: {4}
# respective: {4}
# indices: {4}
# here: {4}
# give: {4}
# below: {4}
# arr: {4}
# arrarrayi: {4}
# printfirst: {4}
# a0: {4}
# printsecond: {4}
# a1: {4}
# last: {4}
# a2: {4}
# printa0: {4}
# a3: {4}
# a1a2: {4}
# now: {4, 5}
# compile: {4}
# above: {4, 5}
# after: {4}
# successful: {4}
# compilation: {4}
# run: {4}
# then: {4}
# first: {4}
# second: {4}
# third: {4}
# forth: {4}
# explanation: {4}
# imported: {4}
# holds: {4}
# printed: {4}
# easily: {4}
# out: {4, 5}
# so: {4}
# httpswwwjavatpointcompythonarrays: {4}
# location: {5}
# valueholding: {5}
# also: {5}
# identifiersince: {5}
# infer: {5}
# smart: {5}
# enough: {5}
# do: {5}
# need: {5}
# names: {5}
# begin: {5}
# letter: {5}
# underscore: {5}
# letters: {5}
# digits: {5}
# identifier: {5}
# naming: {5}
# identifiers: {5}
# things: {5}
# recognize: {5}
# printjohn: {5}
# john: {5}
# object: {5}
# makes: {5}
# shows: {5}
# control: {5}
# center: {5}
# created: {5}
# statement: {5}
# make: {5}
# builtin: {5}
# typejohn: {5}
# factors: {5}
# symbolic: {5}
# pointer: {5}
# indicate: {5}
# lets: {5}
# understand: {5}
# 50: {5}
# image: {5}
# refers: {5}
# suppose: {5}
# assign: {5}
# new: {5}
# same: {5}
# points: {5}
# because: {5}
# does: {5}
# another: {5}
# refer: {5}
# printida: {5}
# printidb: {5}
# reassigned: {5}
# 500: {5}
# 140734982691168: {5}
# 2822056960944: {5}
# highlight: {5}
# similar: {5}
# returned: {5}
# d: {5}
# e: {5}
# f: {5}
# g: {5}
# h: {5}
# na56me: {5}
# i: {5}
# printnamenamenamenamename: {5}
# namename: {5}
# apply: {5}
# tasks: {5}
# either: {5}
# relegating: {5}
# solitary: {5}
# worth: {5}
# doling: {5}
# numerous: {5}
# take: {5}
# look: {5}
# httpswwwjavatpointcompythonvariables: {5}
#
# Term Frequencies:
# python: 41
# data: 16
# types: 13
# every: 3
# value: 6
# has: 3
# a: 71
# datatype: 2
# and: 11
# variables: 7
# can: 16
# hold: 1
# values: 5
# is: 34
# powerfully: 1
# composed: 1
# language: 3
# consequently: 1
# we: 23
# dont: 1
# have: 5
# to: 33
# characterize: 1
# the: 77
# sort: 1
# of: 38
# variable: 18
# while: 2
# announcing: 1
# it: 7
# interpreter: 2
# binds: 1
# implicitly: 1
# its: 4
# type: 21
# 5: 11
# did: 1
# not: 4
# specify: 2
# which: 1
# five: 1
# from: 2
# an: 22
# integer: 6
# will: 4
# automatically: 1
# interpret: 1
# as: 11
# verify: 1
# programused: 1
# thanks: 1
# function: 4
# in: 25
# returns: 1
# passed: 1
# consider: 1
# following: 5
# illustration: 1
# when: 3
# defining: 1
# verifying: 1
# various: 3
# advertisement: 13
# a10: 1
# bhi: 1
# c: 9
# 105: 1
# printtypea: 1
# printtypeb: 1
# printtypec: 1
# output: 10
# int: 2
# str: 2
# float: 4
# standard: 2
# contain: 1
# variety: 1
# on: 3
# other: 2
# hand: 2
# persons: 1
# id: 2
# must: 4
# be: 8
# stored: 3
# their: 1
# name: 15
# string: 9
# storage: 1
# method: 1
# for: 3
# each: 2
# that: 11
# provides: 1
# specified: 1
# by: 9
# list: 3
# pythondefined: 1
# numbers: 4
# sequence: 1
# boolean: 1
# set: 1
# dictionary: 2
# briefly: 1
# discussed: 1
# this: 4
# tutorial: 1
# section: 1
# talk: 1
# about: 1
# single: 3
# one: 6
# them: 1
# exhaustively: 1
# later: 1
# instructional: 1
# exercise: 1
# numeric: 1
# are: 11
# whole: 1
# number: 7
# complex: 4
# qualities: 2
# place: 2
# with: 8
# offers: 1
# determine: 3
# instance: 2
# capability: 1
# utilized: 4
# check: 2
# whether: 1
# item: 4
# specific: 4
# class: 5
# assigned: 3
# generates: 1
# objects: 4
# printthe: 3
# typea: 1
# b: 12
# 405: 1
# typeb: 1
# 13j: 1
# typec: 1
# print: 3
# isinstance13jcomplex: 1
# true: 1
# supports: 2
# three: 1
# kinds: 1
# numerical: 1
# reference: 6
# httpswwwjavatpointcompythondatatypes: 1
# literals: 6
# defined: 2
# given: 6
# or: 4
# constant: 1
# 1: 2
# formed: 1
# enclosing: 1
# text: 2
# quotes: 2
# use: 4
# both: 4
# well: 1
# double: 1
# create: 4
# example: 9
# aman: 1
# 12345: 1
# strings: 5
# there: 2
# two: 4
# supported: 1
# singleline: 2
# terminated: 1
# within: 1
# known: 4
# line: 2
# text1hello: 2
# multiline: 2
# piece: 1
# written: 1
# multiple: 2
# lines: 2
# ways: 2
# adding: 1
# black: 1
# slash: 1
# at: 4
# end: 1
# user: 1
# printtext1: 1
# hellouser: 1
# 2: 7
# using: 5
# triple: 3
# quotation: 1
# marks: 1
# str2welcome: 1
# sssit: 2
# str2: 1
# welcome: 1
# httpswwwjavatpointcompythonliterals: 1
# tuples: 1
# commaseparated: 1
# group: 2
# items: 3
# called: 1
# ordering: 1
# settled: 1
# reiterations: 1
# tuple: 17
# some: 1
# degree: 1
# like: 4
# those: 3
# rundown: 2
# but: 2
# contrast: 1
# unchanging: 1
# main: 1
# difference: 1
# between: 1
# cannot: 1
# alter: 1
# components: 1
# once: 1
# they: 2
# been: 1
# edit: 1
# contents: 1
# suzuki: 1
# audi: 1
# bmw: 1
# skoda: 1
# features: 1
# any: 1
# including: 1
# etc: 2
# contained: 1
# code: 3
# program: 2
# show: 1
# how: 2
# creating: 4
# empty: 2
# emptytuple: 2
# printempty: 1
# having: 2
# integers: 3
# inttuple: 2
# 4: 9
# 6: 11
# 8: 3
# 10: 2
# 12: 2
# 14: 2
# printtuple: 2
# different: 6
# mixedtuple: 2
# 93: 2
# nested: 3
# nestedtuple: 2
# 82: 1
# 3: 2
# printa: 1
# parentheses: 1
# necessary: 1
# construction: 1
# multiples: 1
# pressing: 1
# httpswwwjavatpointcompythontuples: 1
# arrays: 2
# introduction: 1
# article: 1
# discussing: 1
# array: 17
# used: 2
# programming: 1
# java: 1
# r: 1
# javascript: 1
# store: 2
# more: 2
# than: 2
# process: 1
# memory: 2
# allocation: 1
# car1: 1
# lamborghini: 1
# car2: 1
# bugatti: 1
# car3: 1
# koenigsegg: 1
# if: 1
# you: 3
# want: 1
# loop: 1
# through: 2
# cars: 1
# find: 2
# handled: 1
# module: 1
# named: 2
# useful: 1
# manipulate: 1
# only: 1
# traverse: 1
# prints: 1
# all: 1
# elements: 8
# insertion: 1
# adds: 1
# element: 11
# index: 4
# deletion: 1
# deletes: 1
# import: 2
# arrayname: 1
# arraytypecode: 1
# initializers: 1
# accessing: 2
# access: 2
# respective: 1
# indices: 2
# here: 2
# give: 1
# below: 2
# arr: 1
# arrarrayi: 1
# printfirst: 1
# a0: 2
# printsecond: 2
# a1: 4
# last: 2
# a2: 2
# printa0: 1
# a3: 1
# a1a2: 1
# now: 2
# compile: 1
# above: 4
# after: 1
# successful: 1
# compilation: 1
# run: 1
# then: 1
# first: 1
# second: 1
# third: 1
# forth: 1
# explanation: 1
# imported: 1
# holds: 1
# printed: 1
# easily: 1
# out: 2
# so: 1
# httpswwwjavatpointcompythonarrays: 1
# location: 1
# valueholding: 1
# also: 1
# identifiersince: 1
# infer: 1
# smart: 1
# enough: 1
# do: 1
# need: 1
# names: 1
# begin: 1
# letter: 1
# underscore: 1
# letters: 1
# digits: 1
# identifier: 2
# naming: 1
# identifiers: 1
# things: 1
# recognize: 1
# printjohn: 1
# john: 1
# object: 6
# makes: 1
# shows: 1
# control: 1
# center: 1
# created: 1
# statement: 1
# make: 1
# builtin: 1
# typejohn: 1
# factors: 4
# symbolic: 1
# pointer: 1
# indicate: 1
# lets: 2
# understand: 1
# 50: 4
# image: 1
# refers: 2
# suppose: 1
# assign: 2
# new: 2
# same: 2
# points: 1
# because: 1
# does: 1
# another: 1
# refer: 1
# printida: 2
# printidb: 1
# reassigned: 1
# 500: 1
# 140734982691168: 2
# 2822056960944: 1
# highlight: 1
# similar: 1
# returned: 1
# d: 1
# e: 1
# f: 1
# g: 1
# h: 1
# na56me: 2
# i: 1
# printnamenamenamenamename: 1
# namename: 1
# apply: 1
# tasks: 1
# either: 1
# relegating: 1
# solitary: 1
# worth: 1
# doling: 1
# numerous: 1
# take: 1
# look: 1
# httpswwwjavatpointcompythonvariables: 1

# %% [markdown]
# **Boolean Query Processing: AND Operation**

# %%
def boolean_query_and(inverted_index, term1, term2):
    """
    Performs a Boolean AND query on the inverted index.

    Args:
        inverted_index (dict): The inverted index constructed earlier.
        term1 (str): The first query term.
        term2 (str): The second query term.

    Returns:
        set: A set of document IDs that contain both query terms.
    """
    doc_ids_term1 = inverted_index.get(term1, set())
    doc_ids_term2 = inverted_index.get(term2, set())

    return doc_ids_term1 & doc_ids_term2

# Example usage:
term1 = "python"
term2 = "variables"

result = boolean_query_and(inverted_index, term1, term2)

print(f"Documents containing both '{term1}' and '{term2}': {result}")

# Step 3: Perform AND query processing
def boolean_query_and(query_terms, inverted_index):
    # Clean and process the query terms
    cleaned_query = [LEMMATIZER.lemmatize(term.lower()) for term in query_terms]

    # Find document sets for each query term
    doc_sets = [inverted_index[term] for term in cleaned_query if term in inverted_index]

    # Perform intersection to find documents that contain all terms
    if doc_sets:
        result_docs = set.intersection(*doc_sets)
    else:
        result_docs = set()  # If no term exists, return an empty set

    return result_docs
# Out:
# Documents containing both 'python' and 'variables': {1, 5}

# %% [markdown]
# **Main Function**

# %%
def main():
    global final_tokens  # Access the global final_tokens variable
    final_tokens = [] # Initialize final_tokens as a list
    dir_path = '/content/drive/MyDrive/Documents' # Changed file_path to dir_path for clarity
    for filename in os.listdir(dir_path):
        if filename.endswith(".txt"): # Check if item in directory is a file ending in '.txt'
            file_path = os.path.join(dir_path, filename) # Create full path to file
            with open(file_path, 'r', encoding='utf-8') as file:
                for line in file:

                    # Changed 'process_text' to 'clean_text'
                    line_tokens = clean_text(line)
                    final_tokens.extend(line_tokens)

    with open("processed_tokens_Kritika Joshi.txt", "w") as file:
        for i in range(0, len(final_tokens), 3):
            file.write(" ".join(final_tokens[i:i+3]) + "\n")

    print(f"Final tokens: {final_tokens}")
    print(f"Number of tokens: {len(final_tokens)}")

if __name__ == "__main__":
    main()
# Out:
# Final tokens: ['python', 'data', 'types', 'every', 'value', 'has', 'a', 'datatype', 'and', 'variables', 'can', 'hold', 'values', 'python', 'is', 'a', 'powerfully', 'composed', 'language', 'consequently', 'we', 'dont', 'have', 'to', 'characterize', 'the', 'sort', 'of', 'variable', 'while', 'announcing', 'it', 'the', 'interpreter', 'binds', 'the', 'value', 'implicitly', 'to', 'its', 'type', 'a', '5', 'we', 'did', 'not', 'specify', 'the', 'type', 'of', 'the', 'variable', 'a', 'which', 'has', 'the', 'value', 'five', 'from', 'an', 'integer', 'the', 'python', 'interpreter', 'will', 'automatically', 'interpret', 'the', 'variable', 'as', 'an', 'integer', 'we', 'can', 'verify', 'the', 'type', 'of', 'the', 'programused', 'variable', 'thanks', 'to', 'python', 'the', 'type', 'function', 'in', 'python', 'returns', 'the', 'type', 'of', 'the', 'passed', 'variable', 'consider', 'the', 'following', 'illustration', 'when', 'defining', 'and', 'verifying', 'the', 'values', 'of', 'various', 'data', 'types', 'advertisement', 'a10', 'bhi', 'python', 'c', '105', 'printtypea', 'printtypeb', 'printtypec', 'output', 'type', 'int', 'type', 'str', 'type', 'float', 'standard', 'data', 'types', 'a', 'variable', 'can', 'contain', 'a', 'variety', 'of', 'values', 'on', 'the', 'other', 'hand', 'a', 'persons', 'id', 'must', 'be', 'stored', 'as', 'an', 'integer', 'while', 'their', 'name', 'must', 'be', 'stored', 'as', 'a', 'string', 'the', 'storage', 'method', 'for', 'each', 'of', 'the', 'standard', 'data', 'types', 'that', 'python', 'provides', 'is', 'specified', 'by', 'python', 'the', 'following', 'is', 'a', 'list', 'of', 'the', 'pythondefined', 'data', 'types', 'numbers', 'sequence', 'type', 'boolean', 'set', 'dictionary', 'python', 'data', 'types', 'the', 'data', 'types', 'will', 'be', 'briefly', 'discussed', 'in', 'this', 'tutorial', 'section', 'we', 'will', 'talk', 'about', 'every', 'single', 'one', 'of', 'them', 'exhaustively', 'later', 'in', 'this', 'instructional', 'exercise', 'numbers', 'numeric', 'values', 'are', 'stored', 'in', 'numbers', 'the', 'whole', 'number', 'float', 'and', 'complex', 'qualities', 'have', 'a', 'place', 'with', 'a', 'python', 'numbers', 'datatype', 'python', 'offers', 'the', 'type', 'function', 'to', 'determine', 'a', 'variables', 'data', 'type', 'the', 'instance', 'capability', 'is', 'utilized', 'to', 'check', 'whether', 'an', 'item', 'has', 'a', 'place', 'with', 'a', 'specific', 'class', 'when', 'a', 'number', 'is', 'assigned', 'to', 'a', 'variable', 'python', 'generates', 'number', 'objects', 'for', 'instance', 'advertisement', 'advertisement', 'a', '5', 'printthe', 'type', 'of', 'a', 'typea', 'b', '405', 'printthe', 'type', 'of', 'b', 'typeb', 'c', '13j', 'printthe', 'type', 'of', 'c', 'typec', 'print', 'c', 'is', 'a', 'complex', 'number', 'isinstance13jcomplex', 'output', 'the', 'type', 'of', 'a', 'class', 'int', 'the', 'type', 'of', 'b', 'class', 'float', 'the', 'type', 'of', 'c', 'class', 'complex', 'c', 'is', 'complex', 'number', 'true', 'python', 'supports', 'three', 'kinds', 'of', 'numerical', 'data', 'reference', 'httpswwwjavatpointcompythondatatypes', 'python', 'literals', 'python', 'literals', 'can', 'be', 'defined', 'as', 'data', 'that', 'is', 'given', 'in', 'a', 'variable', 'or', 'constant', 'python', 'supports', 'the', 'following', 'literals', '1', 'string', 'literals', 'string', 'literals', 'can', 'be', 'formed', 'by', 'enclosing', 'a', 'text', 'in', 'the', 'quotes', 'we', 'can', 'use', 'both', 'single', 'as', 'well', 'as', 'double', 'quotes', 'to', 'create', 'a', 'string', 'example', 'advertisement', 'aman', '12345', 'types', 'of', 'strings', 'there', 'are', 'two', 'types', 'of', 'strings', 'supported', 'in', 'python', 'a', 'singleline', 'string', 'strings', 'that', 'are', 'terminated', 'within', 'a', 'singleline', 'are', 'known', 'as', 'single', 'line', 'strings', 'example', 'text1hello', 'b', 'multiline', 'string', 'a', 'piece', 'of', 'text', 'that', 'is', 'written', 'in', 'multiple', 'lines', 'is', 'known', ' ...
# Number of tokens: 1377

# %%
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict

# Initialize lemmatizer and stopwords
LEMMATIZER = WordNetLemmatizer()
STOPWORDS = set(stopwords.words('english'))

# Step 1: Clean and tokenize the documents
def clean_text(text):
    """Performs text cleaning: removing special characters, numbers, tokenization, stopword removal, and lemmatization."""

    # Convert to lowercase
    text = text.lower()

    # Remove special characters and numbers using regular expressions
    text = re.sub(r"[^a-zA-Z\s]", "", text)  # Removes special characters and numbers

    # Tokenize the cleaned text
    tokens = word_tokenize(text)

    # Remove stopwords and lemmatize
    cleaned_tokens = [LEMMATIZER.lemmatize(word) for word in tokens if word not in STOPWORDS]

    return cleaned_tokens

# Example documents
documents = [
    "Doc_1: Python Variables: A variable is the name given to a memory location. It has 5 types.",
    "Doc_2: Python Data Types: Every value has a datatype, and variables can hold values. Numbers like 12345 are removed.",
    "Doc_3: Python Literals: Python Literals can be defined as data that is given in a variable or constant like 789.",
    "Doc_4: Python Tuples: A comma-separated group of items is called a Python triple with 3 values.",
    "Doc_5: Python Arrays: The Array is used in every programming language like C, C++, Java, Python, R, JavaScript."
]

# Step 2: Build an inverted index
def build_inverted_index(docs):
    inverted_index = defaultdict(set)  # Maps term -> set of document IDs
    for i, doc in enumerate(docs):
        cleaned_tokens = clean_text(doc)
        for token in cleaned_tokens:
            inverted_index[token].add(i)
    return inverted_index

# Step 3: Perform AND query processing
def boolean_query_and(query_terms, inverted_index):
    # Clean and process the query terms
    cleaned_query = [LEMMATIZER.lemmatize(term.lower()) for term in query_terms]

    # Find document sets for each query term
    doc_sets = [inverted_index[term] for term in cleaned_query if term in inverted_index]

    # Perform intersection to find documents that contain all terms
    if doc_sets:
        result_docs = set.intersection(*doc_sets)
    else:
        result_docs = set()  # If no term exists, return an empty set

    return result_docs

# Build the inverted index
inverted_index = build_inverted_index(documents)

# Step 4: Query example
query = ["python", "variable"]
result = boolean_query_and(query, inverted_index)

# Display results
print(f"Documents that match the query {query}:")
for doc_id in result:
    print(f"Doc_{doc_id + 1}: {documents[doc_id]}")
# Out:
# Documents that match the query ['python', 'variable']:
# Doc_1: Doc_1: Python Variables: A variable is the name given to a memory location. It has 5 types.
# Doc_2: Doc_2: Python Data Types: Every value has a datatype, and variables can hold values. Numbers like 12345 are removed.
# Doc_3: Doc_3: Python Literals: Python Literals can be defined as data that is given in a variable or constant like 789.
